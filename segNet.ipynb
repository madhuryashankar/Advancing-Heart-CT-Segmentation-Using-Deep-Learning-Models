# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Dropout
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from sklearn.model_selection import train_test_split

# Set your data directory
data_dir = '/kaggle/input/trainx/train/train'  # Change this to your dataset path
image_dir = os.path.join(data_dir, "images")
mask_dir = os.path.join(data_dir, "masks")

# List files
image_names = sorted(os.listdir(image_dir))
mask_names = sorted(os.listdir(mask_dir))

common_files = set(image_names) & set(mask_names)
image_names = sorted([name for name in image_names if name in common_files])
mask_names = sorted([name for name in mask_names if name in common_files])

# Ensure image and mask counts match
assert len(image_names) == len(mask_names), "Number of images and masks do not match."

# Preprocess data
input_image_shape = (256, 256)  # Input image size
X, Y = [], []

for img_name, msk_name in zip(image_names, mask_names):
    img_path = os.path.join(image_dir, img_name)
    msk_path = os.path.join(mask_dir, msk_name)

    # Read images and masks
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    msk = cv2.imread(msk_path, cv2.IMREAD_GRAYSCALE)

    # Resize images and masks
    img = cv2.resize(img, input_image_shape).astype(np.float32) / 255.0
    msk = cv2.resize(msk, input_image_shape).astype(np.float32) / 255.0

    # Add channel dimension
    X.append(np.expand_dims(img, axis=-1))  # Shape: (256, 256, 1)
    Y.append(np.expand_dims(msk, axis=-1))  # Shape: (256, 256, 1)

X = np.array(X)
Y = np.array(Y)

print('Dataset shape:', X.shape, Y.shape)

# Split dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print(f"Training set shape: {X_train.shape}, {Y_train.shape}")
print(f"Testing set shape: {X_test.shape}, {Y_test.shape}")

# Define SegNet Model
def create_segnet(input_shape=(256, 256, 1)):
    inputs = Input(input_shape)

    # Encoder
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    c3 = Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    c4 = Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    # Decoder
    u4 = UpSampling2D((2, 2))(p4)
    u4 = Conv2D(512, (3, 3), activation='relu', padding='same')(u4)
    u4 = Conv2D(512, (3, 3), activation='relu', padding='same')(u4)
    u4 = Conv2D(512, (3, 3), activation='relu', padding='same')(u4)

    u3 = UpSampling2D((2, 2))(u4)
    u3 = Conv2D(256, (3, 3), activation='relu', padding='same')(u3)
    u3 = Conv2D(256, (3, 3), activation='relu', padding='same')(u3)
    u3 = Conv2D(256, (3, 3), activation='relu', padding='same')(u3)

    u2 = UpSampling2D((2, 2))(u3)
    u2 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)
    u2 = Conv2D(128, (3, 3), activation='relu', padding='same')(u2)

    u1 = UpSampling2D((2, 2))(u2)
    u1 = Conv2D(64, (3, 3), activation='relu', padding='same')(u1)
    u1 = Conv2D(64, (3, 3), activation='relu', padding='same')(u1)

    outputs = Conv2D(1, (1, 1), activation='sigmoid')(u1)

    model = Model(inputs, outputs)
    return model

# Create and compile the model
model = create_segnet()
model.compile(optimizer=Adam(learning_rate=1e-4), loss=BinaryCrossentropy(), metrics=['accuracy'])

print('Model Summary:')
model.summary()

# Train the model
epochs = 20
batch_size = 16

history = model.fit(
    X_train, Y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, Y_test, batch_size=batch_size)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")

# Save the model
model.save("segnet_model.weights.h5")

# Visualize results
y_pred = model.predict(X_test)

idx = np.random.randint(0, len(X_test))
fig, ax = plt.subplots(1, 3, figsize=(15, 5))

# Input Image
ax[0].imshow(X_test[idx].reshape(256, 256), cmap='gray')
ax[0].set_title('Input Image')
ax[0].axis('off')

# Ground Truth Mask
ax[1].imshow(Y_test[idx].reshape(256, 256), cmap='gray')
ax[1].set_title('Ground Truth Mask')
ax[1].axis('off')

# Predicted Mask
ax[2].imshow(y_pred[idx].reshape(256, 256), cmap='gray')
ax[2].set_title('Predicted Mask')
ax[2].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Dataset shape: (1717, 256, 256, 1) (1717, 256, 256, 1)
# Training set shape: (1373, 256, 256, 1), (1373, 256, 256, 1)
# Testing set shape: (344, 256, 256, 1), (344, 256, 256, 1)
# Model Summary:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)      │ (None, 256, 256, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_95 (Conv2D)              │ (None, 256, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_96 (Conv2D)              │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 128, 128, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_97 (Conv2D)              │ (None, 128, 128, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_98 (Conv2D)              │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 64, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_99 (Conv2D)              │ (None, 64, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_100 (Conv2D)             │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_101 (Conv2D)             │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_26 (MaxPooling2D) │ (None, 32, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_102 (Conv2D)             │ (None, 32, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_103 (Conv2D)             │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_104 (Conv2D)             │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_27 (MaxPooling2D) │ (None, 16, 16, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 32, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_105 (Conv2D)             │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_106 (Conv2D)             │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_107 (Conv2D)             │ (None, 32, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 64, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_108 (Conv2D)             │ (None, 64, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_109 (Conv2D)             │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_110 (Conv2D)             │ (None, 64, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_3 (UpSampling2D)  │ (None, 128, 128, 256)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_111 (Conv2D)             │ (None, 128, 128, 128)  │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_112 (Conv2D)             │ (None, 128, 128, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 256, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_113 (Conv2D)             │ (None, 256, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_114 (Conv2D)             │ (None, 256, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_115 (Conv2D)             │ (None, 256, 256, 1)    │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,627,009 (67.24 MB)
#  Trainable params: 17,627,009 (67.24 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 33s 380ms/step - accuracy: 0.7953 - loss: 0.5296 - val_accuracy: 0.8437 - val_loss: 0.2492
# Epoch 2/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 327ms/step - accuracy: 0.8478 - loss: 0.2211 - val_accuracy: 0.9414 - val_loss: 0.1703
# Epoch 3/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 327ms/step - accuracy: 0.9426 - loss: 0.1455 - val_accuracy: 0.9578 - val_loss: 0.1015
# Epoch 4/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 327ms/step - accuracy: 0.9606 - loss: 0.0920 - val_accuracy: 0.9680 - val_loss: 0.0755
# Epoch 5/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 327ms/step - accuracy: 0.9660 - loss: 0.0778 - val_accuracy: 0.9713 - val_loss: 0.0656
# Epoch 6/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9728 - loss: 0.0612 - val_accuracy: 0.9748 - val_loss: 0.0556
# Epoch 7/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9750 - loss: 0.0557 - val_accuracy: 0.9780 - val_loss: 0.0479
# Epoch 8/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9779 - loss: 0.0482 - val_accuracy: 0.9796 - val_loss: 0.0438
# Epoch 9/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9788 - loss: 0.0458 - val_accuracy: 0.9801 - val_loss: 0.0428
# Epoch 10/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9797 - loss: 0.0442 - val_accuracy: 0.9800 - val_loss: 0.0428
# Epoch 11/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9812 - loss: 0.0400 - val_accuracy: 0.9798 - val_loss: 0.0442
# Epoch 12/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 329ms/step - accuracy: 0.9812 - loss: 0.0401 - val_accuracy: 0.9810 - val_loss: 0.0411
# Epoch 13/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 329ms/step - accuracy: 0.9825 - loss: 0.0370 - val_accuracy: 0.9828 - val_loss: 0.0363
# Epoch 14/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9835 - loss: 0.0341 - val_accuracy: 0.9837 - val_loss: 0.0335
# Epoch 15/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9846 - loss: 0.0315 - val_accuracy: 0.9824 - val_loss: 0.0366
# Epoch 16/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 329ms/step - accuracy: 0.9844 - loss: 0.0320 - val_accuracy: 0.9843 - val_loss: 0.0324
# Epoch 17/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 329ms/step - accuracy: 0.9847 - loss: 0.0309 - val_accuracy: 0.9845 - val_loss: 0.0326
# Epoch 18/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9856 - loss: 0.0283 - val_accuracy: 0.9846 - val_loss: 0.0316
# Epoch 19/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9856 - loss: 0.0288 - val_accuracy: 0.9843 - val_loss: 0.0333
# Epoch 20/20
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 23s 328ms/step - accuracy: 0.9860 - loss: 0.0283 - val_accuracy: 0.9850 - val_loss: 0.0310
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - accuracy: 0.9850 - loss: 0.0321
# Test Accuracy: 98.47%
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step
